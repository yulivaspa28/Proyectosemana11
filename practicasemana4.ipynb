# %%
import numpy as np
import pandas as pd

cols = ["simbología", "Normalizado", "Fabricado", "Combustible", "Aspiración", "Puertas",
        "Estilo", "Llantas", "Motor", "Base", "Longitud", "Ancho", "Altura",
        "Frenado", "Tipo de motor", "Cilindraje","Tamaño del motor", "Sistema", "Diámetro", "Volumen",
        "Compresión", "Caballos fuerza", "Anticongelante", "Ciudad", "Carretera", "Precio"]
df_1er_set=pd.read_csv("autos.csv", names =cols)
df_2do_set=pd.read_csv("Autos1.csv", names =cols)

# %%
import pandas as pd
filename = 'autos.csv'
data = pandas.read_csv(filename, header=0)

print(data.shape)
print (data.head(20))
print (data.tail(20))
# Out:
# (196, 26)
#     3    ?  alfa-romero  gas    std   two  convertible  rwd  front  88.60  \
# 0   3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6
# 1   1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5
# 2   2  164         audi  gas    std  four        sedan  fwd  front   99.8
# 3   2  164         audi  gas    std  four        sedan  4wd  front   99.4
# 4   2    ?         audi  gas    std   two        sedan  fwd  front   99.8
# 5   1  158         audi  gas    std  four        sedan  fwd  front  105.8
# 6   1    ?         audi  gas    std  four        wagon  fwd  front  105.8
# 7   1  158         audi  gas  turbo  four        sedan  fwd  front  105.8
# 8   0    ?         audi  gas  turbo   two    hatchback  4wd  front   99.5
# 9   2  192          bmw  gas    std   two        sedan  rwd  front  101.2
# 10  0  192          bmw  gas    std  four        sedan  rwd  front  101.2
# ...

# %%
df_1er_set.head (10)
# Out:
#    simbología Normalizado    Fabricado Combustible Aspiración Puertas  \
# 0           3           ?  alfa-romero         gas        std     two
# 1           3           ?  alfa-romero         gas        std     two
# 2           1           ?  alfa-romero         gas        std     two
# 3           2         164         audi         gas        std    four
# 4           2         164         audi         gas        std    four
# 5           2           ?         audi         gas        std     two
# 6           1         158         audi         gas        std    four
# 7           1           ?         audi         gas        std    four
# 8           1         158         audi         gas      turbo    four
# 9           0           ?         audi         gas      turbo     two
#
#         Estilo Llantas  Motor   Base  ...  Tamaño del motor  Sistema  \
# 0  convertible     rwd  front   88.6  ...               130     mpfi
# ...

# %%
df_1er_set.tail(10)
# Out:
#      simbología Normalizado   Fabricado Combustible Aspiración Puertas  \
# 187           2          94  volkswagen      diesel      turbo    four
# 188           2          94  volkswagen         gas        std    four
# 189           3           ?  volkswagen         gas        std     two
# 190           3         256  volkswagen         gas        std     two
# 191           0           ?  volkswagen         gas        std    four
# 192           0           ?  volkswagen      diesel      turbo    four
# 193           0           ?  volkswagen         gas        std    four
# 194          -2         103       volvo         gas        std    four
# 195          -1          74       volvo         gas        std    four
# 196          -2         103       volvo         gas        std    four
#
#           Estilo Llantas  Motor   Base  ...  Tamaño del motor  Sistema  \
# 187        sedan     fwd  front   97.3  ...                97      idi
# ...

# %%
print(df_1er_set.max())
# Out:
# simbología              3
# Normalizado             ?
# Fabricado           volvo
# Combustible           gas
# Aspiración          turbo
# Puertas               two
# Estilo              wagon
# Llantas               rwd
# Motor                rear
# Base                120.9
# Longitud            208.1
# Ancho                72.3
# Altura               59.8
# Frenado              4066
# Tipo de motor       rotor
# Cilindraje            two
# Tamaño del motor      326
# Sistema              spfi
# Diámetro                ?
# Volumen                 ?
# Compresión           23.0
# Caballos fuerza         ?
# Anticongelante          ?
# Ciudad                 49
# Carretera              54
# Precio                  ?
# dtype: object

# %%
print(df_1er_set.min())
# Out:
# simbología                   -2
# Normalizado                 101
# Fabricado           alfa-romero
# Combustible              diesel
# Aspiración                  std
# Puertas                       ?
# Estilo              convertible
# Llantas                     4wd
# Motor                     front
# Base                       86.6
# Longitud                  141.1
# Ancho                      60.3
# Altura                     47.8
# Frenado                    1488
# Tipo de motor              dohc
# Cilindraje                eight
# Tamaño del motor             61
# Sistema                    1bbl
# Diámetro                   2.54
# Volumen                    2.07
# Compresión                  7.0
# Caballos fuerza             100
# Anticongelante             4150
# Ciudad                       13
# Carretera                    16
# Precio                    10198
# dtype: object

# %%
print(df_1er_set.median())#ejemplo para encoentrar la media
# Out:
# simbología             1.0
# Base                  96.5
# Longitud             172.6
# Ancho                 65.4
# Altura                53.9
# Frenado             2405.0
# Tamaño del motor     110.0
# Compresión             9.0
# Ciudad                25.0
# Carretera             30.0
# dtype: float64
# C:\Users\yulia\AppData\Local\Temp\ipykernel_3636\76067005.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df_1er_set.median())#ejemplo para encoentrar la media

# %%
print(df_1er_set.std()) #desviación estándar
# Out:
# simbología            1.202746
# Base                  5.866965
# Longitud             12.213912
# Ancho                 2.128306
# Altura                2.438891
# Frenado             520.401159
# Tamaño del motor     42.282594
# Compresión            3.934467
# Ciudad                6.566717
# Carretera             6.908644
# dtype: float64
# C:\Users\yulia\AppData\Local\Temp\ipykernel_3636\2807916020.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df_1er_set.std()) #desviación estándar

# %%
print(df_1er_set.loc[0,:]) #Seleccionar los valores de la primera fila del DataFrame
# Out:
# simbología                    3
# Normalizado                   ?
# Fabricado           alfa-romero
# Combustible                 gas
# Aspiración                  std
# Puertas                     two
# Estilo              convertible
# Llantas                     rwd
# Motor                     front
# Base                       88.6
# Longitud                  168.8
# Ancho                      64.1
# Altura                     48.8
# Frenado                    2548
# Tipo de motor              dohc
# Cilindraje                 four
# Tamaño del motor            130
# Sistema                    mpfi
# Diámetro                   3.47
# Volumen                    2.68
# Compresión                  9.0
# Caballos fuerza             111
# Anticongelante             5000
# Ciudad                       21
# Carretera                    27
# Precio                    13495
# Name: 0, dtype: object

# %%
print(df_1er_set.isnull())#Datos nulos en el DataFrame
# Out:
#      simbología  Normalizado  Fabricado  Combustible  Aspiración  Puertas  \
# 0         False        False      False        False       False    False
# 1         False        False      False        False       False    False
# 2         False        False      False        False       False    False
# 3         False        False      False        False       False    False
# 4         False        False      False        False       False    False
# ..          ...          ...        ...          ...         ...      ...
# 192       False        False      False        False       False    False
# 193       False        False      False        False       False    False
# 194       False        False      False        False       False    False
# 195       False        False      False        False       False    False
# 196       False        False      False        False       False    False
#
#      Estilo  Llantas  Motor   Base  ...  Tamaño del motor  Sistema  Diámetro  \
# ...

# %%
print(df_1er_set.isnull().sum())
# Out:
# simbología          0
# Normalizado         0
# Fabricado           0
# Combustible         0
# Aspiración          0
# Puertas             0
# Estilo              0
# Llantas             0
# Motor               0
# Base                0
# Longitud            0
# Ancho               0
# Altura              0
# Frenado             0
# Tipo de motor       0
# Cilindraje          0
# Tamaño del motor    0
# Sistema             0
# Diámetro            0
# Volumen             0
# Compresión          0
# Caballos fuerza     0
# Anticongelante      0
# Ciudad              0
# Carretera           0
# Precio              0
# dtype: int64

# %%
print(df_1er_set.dropna()) #Eliminar datos perdidos del DataFrame
# Out:
#      simbología Normalizado    Fabricado Combustible Aspiración Puertas  \
# 0             3           ?  alfa-romero         gas        std     two
# 1             3           ?  alfa-romero         gas        std     two
# 2             1           ?  alfa-romero         gas        std     two
# 3             2         164         audi         gas        std    four
# 4             2         164         audi         gas        std    four
# ..          ...         ...          ...         ...        ...     ...
# 192           0           ?   volkswagen      diesel      turbo    four
# 193           0           ?   volkswagen         gas        std    four
# 194          -2         103        volvo         gas        std    four
# 195          -1          74        volvo         gas        std    four
# 196          -2         103        volvo         gas        std    four
#
#           Estilo Llantas  Motor   Base  ...  Tamaño del motor  Sistema  \
# ...

# %%
print(df_1er_set.describe())
# Out:
#        simbología        Base    Longitud       Ancho      Altura  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#            Frenado  Tamaño del motor  Compresión      Ciudad   Carretera
# count   197.000000        197.000000  197.000000  197.000000  197.000000
# mean   2534.796954        126.263959   10.128020   25.416244   30.984772
# std     520.401159         42.282594    3.934467    6.566717    6.908644
# min    1488.000000         61.000000    7.000000   13.000000   16.000000
# ...
